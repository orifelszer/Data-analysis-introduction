# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
#url = 'C:/Users/lihi/OneDrive - ariel.ac.il/Ariel_Teachings/a_intro to data analysis/b_units of code/data/fitness analysis.csv'
#fit_df = pd.read_csv(url)
#fit_df.head(2)
url='violence_data.csv'
data_df = pd.read_csv(url)
data_df.columns
#DONT USE THIS WAY CAUSE IS IN MY PC AND NO ONE CAN SEE IT
# Out:
# Index(['RecordID', 'Country', 'Gender', 'Demographics Question',
#        'Demographics Response', 'Question', 'Survey Year', 'Value'],
#       dtype='object')

# %% [markdown]
# CORRECT WAY OF CALLING THE DATA

# %%
url2= 'https://raw.githubusercontent.com/orifelszer/project/main/violence_data.csv'
data_df2= pd.read_csv(url2)
just_women= data_df2.loc[data_df2.Gender== 'F']
just_women
# Out:
#        RecordID      Country Gender Demographics Question  \
# 0             1  Afghanistan      F        Marital status
# 1             1  Afghanistan      F             Education
# 2             1  Afghanistan      F             Education
# 3             1  Afghanistan      F             Education
# 4             1  Afghanistan      F        Marital status
# ...         ...          ...    ...                   ...
# 12505       210     Zimbabwe      F             Residence
# 12506       280     Zimbabwe      F             Residence
# 12507       280     Zimbabwe      F             Residence
# 12508       350     Zimbabwe      F             Residence
# 12509       350     Zimbabwe      F             Residence
#
#               Demographics Response                                 Question  \
# 0                     Never married                ... if she burns the food
# 1                            Higher                ... if she burns the food
# 2                         Secondary                ... if she burns the food
# 3                           Primary                ... if she burns the food
# 4      Widowed, divorced, separated                ... if she burns the food
# ...                             ...                                      ...
# 12505                         Urban  ... if she goes out without telling him
# 12506                         Rural         ... if she neglects the children
# 12507                         Urban         ... if she neglects the children
# 12508                         Rural  ... if she refuses to have sex with him
# 12509                         Urban  ... if she refuses to have sex with him
#
#       Survey Year  Value
# 0      01/01/2015    NaN
# 1      01/01/2015   10.1
# 2      01/01/2015   13.7
# 3      01/01/2015   13.8
# 4      01/01/2015   13.8
# ...           ...    ...
# 12505  01/01/2015   14.2
# 12506  01/01/2015   24.3
# 12507  01/01/2015   16.7
# 12508  01/01/2015   18.2
# 12509  01/01/2015    8.6
#
# [6300 rows x 8 columns]

# %%
data_df2[['Value']].isnull().sum()
data_df2.dropna()
#WHOEVER DOESNT ANSWER THE SURVEY ITS NOT RELEVANT FOR US
# Out:
#        RecordID      Country Gender Demographics Question  \
# 1             1  Afghanistan      F             Education
# 2             1  Afghanistan      F             Education
# 3             1  Afghanistan      F             Education
# 4             1  Afghanistan      F        Marital status
# 5             1  Afghanistan      F            Employment
# ...         ...          ...    ...                   ...
# 12595       210     Zimbabwe      M             Residence
# 12596       280     Zimbabwe      M             Residence
# 12597       280     Zimbabwe      M             Residence
# 12598       350     Zimbabwe      M             Residence
# 12599       350     Zimbabwe      M             Residence
#
#               Demographics Response                                 Question  \
# 1                            Higher                ... if she burns the food
# 2                         Secondary                ... if she burns the food
# 3                           Primary                ... if she burns the food
# 4      Widowed, divorced, separated                ... if she burns the food
# 5                 Employed for kind                ... if she burns the food
# ...                             ...                                      ...
# 12595                         Urban  ... if she goes out without telling him
# 12596                         Rural         ... if she neglects the children
# 12597                         Urban         ... if she neglects the children
# 12598                         Rural  ... if she refuses to have sex with him
# 12599                         Urban  ... if she refuses to have sex with him
#
#       Survey Year  Value
# 1      01/01/2015   10.1
# 2      01/01/2015   13.7
# 3      01/01/2015   13.8
# 4      01/01/2015   13.8
# 5      01/01/2015   17.0
# ...           ...    ...
# 12595  01/01/2015   11.8
# 12596  01/01/2015   20.1
# 12597  01/01/2015   15.0
# 12598  01/01/2015    7.2
# 12599  01/01/2015    3.7
#
# [11187 rows x 8 columns]

# %%
demographics_df = data_df2.groupby(["Demographics Question", "Demographics Response"])["Value"].agg(["median", "max", "min", "mean"]).reset_index()
demographics_df.columns = ["Question", "Response", "Median", "Max", "Min", "Mean"]
print("Violence % median, min, max, and mean per demographic group")
demographics_df.sort_values(["Question", "Median"])

#NEED TO EXPLAINN IT
# Out:
# Violence % median, min, max, and mean per demographic group
#           Question                      Response  Median   Max  Min       Mean
# 2              Age                         35-49   14.15  81.0  0.2  19.336412
# 1              Age                         25-34   14.45  81.5  0.1  19.703562
# 0              Age                         15-24   17.50  80.1  0.1  21.084169
# 3        Education                        Higher    4.20  74.6  0.0   8.898670
# 6        Education                     Secondary   13.05  76.7  0.2  17.378892
# 5        Education                       Primary   18.40  80.5  0.1  22.819093
# 4        Education                  No education   21.55  82.0  0.0  25.403125
# 9       Employment                    Unemployed   14.55  80.1  0.0  19.539710
# 7       Employment             Employed for cash   14.85  81.5  0.1  19.553804
# 8       Employment             Employed for kind   20.15  86.9  0.3  24.445541
# 10  Marital status    Married or living together   14.80  82.1  0.2  20.181003
# 11  Marital status                 Never married   14.90  72.1  0.0  18.704360
# 12  Marital status  Widowed, divorced, separated   17.15  75.9  0.0  20.683511
# 14       Residence                         Urban   11.05  74.4  0.1  15.895778
# 13       Residence                         Rural   19.00  82.1  0.2  23.294063

# %%
demographics_df = data_df2.groupby(["Demographics Question", "Demographics Response"])["Value"].agg(["median", "mean"]).reset_index()
demographics_df.columns = ["Question", "Response", "Median", "Mean"]
print("Violence % median, and mean per demographic group")
demographics_df.sort_values(["Question", "Median"])
# Out:
# Violence % median, and mean per demographic group
#           Question                      Response  Median       Mean
# 2              Age                         35-49   14.15  19.336412
# 1              Age                         25-34   14.45  19.703562
# 0              Age                         15-24   17.50  21.084169
# 3        Education                        Higher    4.20   8.898670
# 6        Education                     Secondary   13.05  17.378892
# 5        Education                       Primary   18.40  22.819093
# 4        Education                  No education   21.55  25.403125
# 9       Employment                    Unemployed   14.55  19.539710
# 7       Employment             Employed for cash   14.85  19.553804
# 8       Employment             Employed for kind   20.15  24.445541
# 10  Marital status    Married or living together   14.80  20.181003
# 11  Marital status                 Never married   14.90  18.704360
# 12  Marital status  Widowed, divorced, separated   17.15  20.683511
# 14       Residence                         Urban   11.05  15.895778
# 13       Residence                         Rural   19.00  23.294063

# %%
question_df = data_df.groupby(["Question"])["Value"].agg(["median", "max", "min", "mean"]).reset_index()
question_df.columns = ["Question", "Median", "Max", "Min", "Mean"]
print("Violence % median, min, max, and mean per question asked")
question_df.sort_values(["Median"])
# Out:
# Violence % median, min, max, and mean per question asked
#                                   Question  Median   Max  Min       Mean
# 2                ... if she burns the food     6.4  56.7  0.0   9.203445
# 5  ... if she refuses to have sex with him     9.0  68.7  0.0  13.209613
# 1               ... if she argues with him    15.7  76.5  0.0  18.983652
# 3  ... if she goes out without telling him    16.4  77.0  0.0  20.046321
# 4         ... if she neglects the children    20.8  75.6  0.0  23.461249
# 0     ... for at least one specific reason    31.0  86.9  0.0  33.217152

# %%
countries= data_df.groupby(["Country","Question"])["Value"].agg(["median", "max", "min", "mean"]).reset_index()
countries
# Out:
#          Country                                 Question  median   max   min  \
# 0    Afghanistan     ... for at least one specific reason   74.05  86.9  48.8
# 1    Afghanistan               ... if she argues with him   49.00  60.6  31.4
# 2    Afghanistan                ... if she burns the food   10.65  20.8   4.5
# 3    Afghanistan  ... if she goes out without telling him   62.30  69.3  36.5
# 4    Afghanistan         ... if she neglects the children   32.60  50.6  19.6
# ..           ...                                      ...     ...   ...   ...
# 415     Zimbabwe               ... if she argues with him   15.15  26.4   2.4
# 416     Zimbabwe                ... if she burns the food    7.35  17.0   1.1
# 417     Zimbabwe  ... if she goes out without telling him   21.30  37.8   2.9
# 418     Zimbabwe         ... if she neglects the children   20.10  33.3   4.6
# 419     Zimbabwe  ... if she refuses to have sex with him    8.60  28.5   2.9
#
#           mean
# 0    73.203571
# 1    49.582143
# 2    12.264286
# 3    60.310714
# 4    36.425000
# ..         ...
# 415  15.300000
# 416   7.080000
# 417  20.466667
# 418  20.096667
# 419  10.723333
#
# [420 rows x 6 columns]

# %%
demoq_df = data_df.groupby(["Demographics Question", "Demographics Response", "Question"])["Value"].agg(["median", "mean"]).reset_index()
demoq_df.columns = ["Demographics Question", "Demographics Response", "Question", "Median", "Mean"]
print("Violence % median, and mean per demographic group and question asked")
demoq_df = demoq_df.sort_values(["Demographics Question", "Demographics Response", "Median"])
demoq_df.head()
# Out:
# Violence % median, and mean per demographic group and question asked
#   Demographics Question Demographics Response  \
# 2                   Age                 15-24
# 5                   Age                 15-24
# 3                   Age                 15-24
# 1                   Age                 15-24
# 4                   Age                 15-24
#
#                                   Question  Median       Mean
# 2                ... if she burns the food    8.50  10.098387
# 5  ... if she refuses to have sex with him   10.05  13.404762
# 3  ... if she goes out without telling him   18.40  21.026563
# 1               ... if she argues with him   18.65  20.304032
# 4         ... if she neglects the children   23.20  25.306250

# %%
myBoxplot= demoq_df[['Median','Demographics Question']]
ax= sns.boxplot( data= myBoxplot, x='Median',y='Demographics Question')

# %%
myBarPlot= demoq_df[['Median','Demographics Response','Demographics Question']]
ax2= sns.boxplot( data= myBarPlot, x='Median',y='Demographics Response')

# %%
fig, axes = plt.subplots(2,1, figsize=(12, 12))
MyOrder= ['ax3','ax4']
plt.subplots_adjust(wspace = 0.3)
#sns.boxplot( data= myBarPlot, x='Median',y='Demographics Response')
#sns.histplot(x="Value", hue="Demographics Response",  data=data_df2)
sns.barplot(data=myBarPlot, x = "Median", y='Demographics Question')
# Out:
# <AxesSubplot:xlabel='Median', ylabel='Demographics Question'>

# %%
question_df2 = data_df2.groupby(["Country","Question"])["Value"].agg(["median", "max", "min", "mean"])

# %%
data_df2.pivot_table('Value', index='Country', columns='Demographics Question', aggfunc='median')
# Out:
# Demographics Question    Age  Education  Employment  Marital status  Residence
# Country
# Afghanistan            46.55      41.05       47.95           39.80      46.35
# Albania                 3.60       4.00        3.85            3.95       3.40
# Angola                 12.10      10.80       12.05           12.40      11.90
# Armenia                 6.80       6.35        8.15            6.25       6.70
# Azerbaijan             34.80      35.65       34.35           32.15      35.25
# ...                      ...        ...         ...             ...        ...
# Uganda                 23.05      20.05       26.35           26.25      22.05
# Ukraine                 2.25       2.30        3.00            2.20       2.70
# Yemen                  30.85      20.15       27.90           30.30      23.90
# Zambia                 25.10      19.65       25.50           24.90      23.45
# Zimbabwe               15.35      17.40       17.80           16.65      15.85
#
# [70 rows x 5 columns]

# %%
hola= data_df2.pivot_table('Value', index='Country', columns='Demographics Response') 
hola
# Out:
# Demographics Response      15-24      25-34      35-49  Employed for cash  \
# Country
# Afghanistan            44.875000  45.158333  44.958333          44.833333
# Albania                 3.666667   4.316667   4.775000           3.508333
# Angola                 13.591667  12.366667  12.458333          13.141667
# Armenia                 8.400000   8.458333   8.375000           8.308333
# Azerbaijan             32.566667  33.391667  31.366667          29.800000
# ...                          ...        ...        ...                ...
# Uganda                 29.741667  22.433333  22.600000          24.475000
# Ukraine                 2.516667   4.000000   3.558333           3.416667
# Yemen                  27.933333  29.466667  31.933333          22.150000
# Zambia                 26.716667  24.258333  23.600000          24.283333
# Zimbabwe               23.433333  15.775000  12.741667          15.933333
#
# Demographics Response  Employed for kind     Higher  \
# Country
# Afghanistan                    46.850000  30.166667
# Albania                         6.508333   1.591667
# Angola                         15.650000   2.550000
# Armenia                        19.233333   5.141667
# Azerbaijan                     34.925000  18.633333
# ...                                  ...        ...
# Uganda                         29.450000  10.083333
# Ukraine                         4.475000   2.375000
# Yemen                          39.900000  10.316667
# Zambia                         34.241667   5.725000
# Zimbabwe                       20.908333   5.000000
#
# Demographics Response  Married or living together  Never married  \
# Country
# Afghanistan                             45.108333            NaN
# Albania                                  4.700000       3.441667
# Angola                                  13.266667      11.775000
# Armenia                                  8.433333       8.116667
# Azerbaijan                              32.975000      30.783333
# ...                                           ...            ...
# Uganda                                  23.891667      27.966667
# Ukraine                                  2.808333       3.300000
# Yemen                                   30.916667      26.683333
# Zambia                                  25.166667      23.675000
# Zimbabwe                                15.916667      21.425000
#
# Demographics Response  No education    Primary      Rural  Secondary  \
# Country
# Afghanistan               47.408333  42.675000  46.883333  41.016667
# Albania                   15.791667   6.300000   5.408333   3.750000
# Angola                    19.600000  16.775000  20.108333   8.958333
# Armenia                         NaN  10.066667  12.675000  11.416667
# Azerbaijan                55.516667  44.016667  39.950000  34.441667
# ...                             ...        ...        ...        ...
# Uganda                    27.575000  30.283333  28.066667  20.858333
# Ukraine                         NaN        NaN   4.366667   4.466667
# Yemen                     37.250000  28.350000  34.550000  17.583333
# Zambia                    28.166667  30.883333  31.141667  21.150000
# Zimbabwe                  29.725000  24.191667  21.400000  17.350000
#
# Demographics Response  Unemployed      Urban  Widowed, divorced, separated
# Country
# Afghanistan             43.708333  38.541667                     35.383333
# Albania                  4.791667   3.575000                      9.141667
# Angola                  11.200000   9.950000                     16.641667
# Armenia                  7.225000   5.316667                     12.583333
# Azerbaijan              32.666667  26.341667                     29.716667
# ...                           ...        ...                           ...
# Uganda                  28.258333  19.016667                     27.908333
# Ukraine                  3.200000   3.000000                      6.516667
# Yemen                   29.300000  19.166667                     28.816667
# Zambia                  22.241667  18.075000                     26.100000
# Zimbabwe                20.483333  12.483333                     15.791667
#
# [70 rows x 15 columns]

# %%
sns.barplot( data= hola, x='Age',y='Value')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 sns.barplot( data= hola, x='Age',y='Value')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3182, in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3169 @_deprecate_positional_args
#    3170 def barplot(
#    3171     *,
#    (...)
#    3179     **kwargs,
#    3180 ):
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
#    3185                           errcolor, errwidth, capsize, dodge)
#    3187     if ax is None:
#    3188         ax = plt.gca()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:1584, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1579 def __init__(self, x, y, hue, data, order, hue_order,
#    1580              estimator, ci, n_boot, units, seed,
#    1581              orient, color, palette, saturation, errcolor,
#    1582              errwidth, capsize, dodge):
#    1583     """Initialize the plotter."""
# -> 1584     self.establish_variables(x, y, hue, data, orient,
#    1585                              order, hue_order, units)
#    1586     self.establish_colors(color, palette, saturation)
#    1587     self.estimate_statistic(estimator, ci, n_boot, seed)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:153, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151     if isinstance(var, str):
#     152         err = "Could not interpret input '{}'".format(var)
# --> 153         raise ValueError(err)
#     155 # Figure out the plotting orientation
#     156 orient = infer_orient(
#     157     x, y, orient, require_numeric=self.require_numeric
#     158 )
#
# ValueError: Could not interpret input 'Value'

# %%
education= data_df2[data_df2.loc[:,"Demographics Question"] == "Education"]
education
# Out:
#        RecordID      Country Gender Demographics Question  \
# 1             1  Afghanistan      F             Education
# 2             1  Afghanistan      F             Education
# 3             1  Afghanistan      F             Education
# 13            1  Afghanistan      F             Education
# 16            1  Afghanistan      M             Education
# ...         ...          ...    ...                   ...
# 12547       280     Zimbabwe      M             Education
# 12548       350     Zimbabwe      M             Education
# 12549       350     Zimbabwe      M             Education
# 12550       350     Zimbabwe      M             Education
# 12551       350     Zimbabwe      M             Education
#
#       Demographics Response                                 Question  \
# 1                    Higher                ... if she burns the food
# 2                 Secondary                ... if she burns the food
# 3                   Primary                ... if she burns the food
# 13             No education                ... if she burns the food
# 16                   Higher                ... if she burns the food
# ...                     ...                                      ...
# 12547             Secondary         ... if she neglects the children
# 12548                Higher  ... if she refuses to have sex with him
# 12549          No education  ... if she refuses to have sex with him
# 12550               Primary  ... if she refuses to have sex with him
# 12551             Secondary  ... if she refuses to have sex with him
#
#       Survey Year  Value
# 1      01/01/2015   10.1
# 2      01/01/2015   13.7
# 3      01/01/2015   13.8
# 13     01/01/2015   19.1
# 16     01/01/2015    4.5
# ...           ...    ...
# 12547  01/01/2015   18.0
# 12548  01/01/2015    2.9
# 12549  01/01/2015   16.2
# 12550  01/01/2015    8.6
# 12551  01/01/2015    5.5
#
# [3360 rows x 8 columns]

# %% [markdown]
# We want to show the contrast among the percentage of people that answered the survey and the education levels.

# %%
plt.figure(figsize = (7,6))
ax= sns.barplot( data= education, y='Value',x='Question', hue='Demographics Response',ci = None);
plt.xticks(rotation=75, fontsize= 12);
plt.legend(title='Education level', loc=(1.04,0.5))
plt.xlabel('Questions',fontsize=17)
plt.ylabel('% of response',fontsize=17);
